# %%
# !git pull
import warnings
warnings.filterwarnings("ignore")


def norm_latext_tab(tab):
    tab = tab[tab.index(r'\begin{tabular}'): tab.index(r'\end{tabular}')+len(r'\end{tabular}')]
    tab = tab.replace('{tabular}', '{array}')
    tab = tab.replace('r@{}c@{}l', 'c')
    tab = tab.replace(r'& $\pm$ &', '\pm')
    tab = tab.replace(r'& \textbf{$\pm$} &', r'\textbf{$\pm$}')
    tab = tab.replace(r'\multirow{4}{*}', '')
    tab = tab.replace(r'\multicolumn{3}{c}', '')
    return tab
# Out:
# Already up to date.

# %%
# %matplotlib inline
# %run ../code/online/toy_env.py

# %%
# %matplotlib inline
# %run plot_toy.py

# %%
# %matplotlib inline
warnings.filterwarnings("ignore", category=DeprecationWarning)
# %run plot_online.py

# %%
from IPython.display import Latex
with open('./online_1m.tex','r')as f:
    tab = norm_latext_tab(f.read())
Latex(tab)
# Out:
# \begin{array}{lcccccc}
# \hline
# \textbf{Environment} & {\textbf{ALH-a (our)}} & {\textbf{ALH-g (our)}} & {\textbf{TD3}} & {\textbf{MBPO}} & {\textbf{DDPG}} & {\textbf{PPO}} \\
# \hline
# HalfCheetah-v3 & \textbf{7924.09} \textbf{$\pm$} \textbf{636.61} & \textbf{8508.09} \textbf{$\pm$} \textbf{610.20} & 7563.45 \pm 996.14 & 6942.36 \pm 1108.77 & 6564.98 \pm 517.34 & 412.87 \pm 131.65 \\
# Hopper-v3 & \textbf{3431.29} \textbf{$\pm$} \textbf{162.91} & \textbf{3439.50} \textbf{$\pm$} \textbf{145.63} & 3273.77 \pm 285.26 & 2951.81 \pm 734.71 & 2657.49 \pm 685.31 & 2463.91 \pm 741.83 \\
# Walker2d-v3 & \textbf{4072.41} \textbf{$\pm$} \textbf{827.26} & \textbf{4225.65} \textbf{$\pm$} \textbf{382.86} & 3612.88 \pm 860.95 & 1774.64 \pm 1117.82 & 2698.40 \pm 680.68 & 888.80 \pm 237.93 \\
# Ant-v3 & \textbf{5395.55} \textbf{$\pm$} \textbf{353.28} & \textbf{5179.31} \textbf{$\pm$} \textbf{606.92} & 4884.83 \pm 675.88 & 1962.42 \pm 797.76 & 1248.39 \pm 631.99 & 22.49 \pm 40.47 \\
# Humanoid-v3 & \textbf{5086.73} \textbf{$\pm$} \textbf{212.45} & \textbf{5036.58} \textbf{$\pm$} \textbf{253.53} & 5031.64 \pm 182.01 & 475.70 \pm 156.08 & 352.75 \pm 95.58 & 424.07 \pm 14.09 \\
# Reacher-v2 & -5.94 \pm 0.53 & \textbf{-5.79} \textbf{$\pm$} \textbf{0.76} & -6.06 \pm 0.63 & -27.51 \pm 24.71 & -8.55 \pm 0.68 & \textbf{-5.17} \textbf{$\pm$} \textbf{0.37} \\
# InvertedDoublePendulum-v2 & 9358.61 \pm 2.57 & \textbf{9359.61} \textbf{$\pm$} \textbf{0.19} & 7492.54 \pm 3732.47 & \textbf{9359.84} \textbf{$\pm$} \textbf{0.14} & 9358.38 \pm 1.87 & 9094.67 \pm 402.77 \\
# InvertedPendulum-v2 & \textbf{1000.00} \textbf{$\pm$} \textbf{0.00} & \textbf{1000.00} \textbf{$\pm$} \textbf{0.00} & \textbf{1000.00} \textbf{$\pm$} \textbf{0.00} & \textbf{1000.00} \textbf{$\pm$} \textbf{0.00} & \textbf{1000.00} \textbf{$\pm$} \textbf{0.00} & \textbf{1000.00} \textbf{$\pm$} \textbf{0.00} \\
# \hline
# Avg (normalized) & {\textbf{85.46}} & {\textbf{86.50}} & {67.27} & {36.99} & {44.70} & {23.40} \\
# \hline
# \end{array}

# %%
# %matplotlib inline
warnings.filterwarnings("ignore", category=DeprecationWarning)
# %run plot_ablation_online_merge.py

# %%
# !python plot_ablation_tab.py
from IPython.display import Latex
with open('./ablation.tex','r')as f:
    tab = norm_latext_tab(f.read())
Latex(tab)
# Out:
# \begin{array}{llcccc}
# \hline
# \textbf{Aggregate type} & \textbf{Ablation Setting} & \textbf{ALH-g} & \textbf{ALH-a} & \textbf{ALH+BC (offline)} & \textbf{ALH (offline)} \\
# \hline
# {Max} & our & \textbf{100\%} & \textbf{100\%} & 100\% & 100\% \\
#   & no detach & 88.94\% & 95.49\% & 36.92\% & 2.56\% \\
#   & no localization & 85.00\% & 96.10\% & 99.43\% & \textbf{114.78\%} \\
#   & no adaptation & 85.42\% & 87.67\% & \textbf{101.43\%} & 100.63\% \\
# \hline
# {Average} & our & \textbf{100\%} & \textbf{100\%} & \textbf{100\%} & \textbf{100\%} \\
#   & no detach & 91.71\% & 95.26\% & 30.98\% & -5.92\% \\
#   & no localization & 88.51\% & 95.53\% & 99.70\% & 88.31\% \\
#   & no adaptation & 88.49\% & 88.43\% & 97.98\% & 98.62\% \\
# \hline
# \end{array}

# %%
# %matplotlib inline
warnings.filterwarnings("ignore", category=DeprecationWarning)
# %run plot_offline.py

# %%
# !python plot_ablation_tab.py
from IPython.display import Latex
with open('./offline_1m.tex','r')as f:
    tab = norm_latext_tab(f.read())
Latex(tab)
# Out:
# \begin{array}{lcccccc}
# \hline
# \textbf{Environment} & {\textbf{ALH+BC (our)}} & {\textbf{ALH (our)}} & {\textbf{TD3+BC}} & {\textbf{BC}} & {\textbf{DT}} & {\textbf{APE-V}} \\
# \hline
# halfcheetah-random-v2 & 17.30 \pm 0.07 & \textbf{35.85} \textbf{$\pm$} \textbf{0.14} & 14.88 \pm 0.02 & 2.26 \pm 0.00 & {-} & {29.9} \\
# hopper-random-v2 & 9.88 \pm 0.02 & \textbf{34.51} \textbf{$\pm$} \textbf{0.14} & 32.30 \pm 0.00 & 8.05 \pm 0.45 & {-} & {31.3} \\
# walker2d-random-v2 & 7.40 \pm 0.16 & \textbf{20.27} \textbf{$\pm$} \textbf{0.11} & \textbf{21.95} \textbf{$\pm$} \textbf{0.00} & 5.75 \pm 0.39 & {-} & {15.5} \\
# \hline
# halfcheetah-medium-v2 & 49.96 \pm 0.47 & 47.91 \pm 2.30 & 48.81 \pm 0.30 & 43.09 \pm 0.26 & {42.6} & {\textbf{69.1}} \\
# hopper-medium-v2 & 66.88 \pm 1.41 & 1.78 \pm 0.00 & \textbf{74.77} \textbf{$\pm$} \textbf{4.09} & 63.58 \pm 2.25 & {67.6} & {-} \\
# walker2d-medium-v2 & 86.84 \pm 0.34 & 1.55 \pm 0.24 & 85.68 \pm 0.95 & 77.80 \pm 1.27 & {74.0} & {\textbf{90.3}} \\
# \hline
# halfcheetah-expert-v2 & \textbf{98.90} \textbf{$\pm$} \textbf{0.34} & 3.75 \pm 0.15 & \textbf{97.81} \textbf{$\pm$} \textbf{0.36} & 93.81 \pm 0.24 & {-} & {-} \\
# hopper-expert-v2 & \textbf{112.95} \textbf{$\pm$} \textbf{0.37} & 1.59 \pm 0.00 & \textbf{112.46} \textbf{$\pm$} \textbf{0.04} & \textbf{112.61} \textbf{$\pm$} \textbf{0.18} & {-} & {-} \\
# walker2d-expert-v2 & \textbf{111.21} \textbf{$\pm$} \textbf{0.09} & 1.87 \pm 0.28 & \textbf{110.99} \textbf{$\pm$} \textbf{0.05} & \textbf{109.36} \textbf{$\pm$} \textbf{0.10} & {-} & {-} \\
# \hline
# halfcheetah-medium-expert-v2 & 96.12 \pm 0.27 & 10.53 \pm 1.19 & 96.55 \pm 0.40 & 74.53 \pm 4.47 & {86.8} & {\textbf{101.4}} \\
# hopper-medium-expert-v2 & \textbf{112.74} \textbf{$\pm$} \textbf{0.18} & 1.68 \pm 0.00 & \textbf{112.26} \textbf{$\pm$} \textbf{0.23} & 89.40 \pm 8.10 & {107.6} & {105.72} \\
# walker2d-medium-expert-v2 & \textbf{111.29} \textbf{$\pm$} \textbf{0.07} & 0.21 \pm 0.00 & \textbf{111.32} \textbf{$\pm$} \textbf{0.13} & \textbf{109.45} \textbf{$\pm$} \textbf{0.16} & {108.1} & {\textbf{110.0}} \\
# \hline
# halfcheetah-medium-replay-v2 & 46.55 \pm 0.23 & 49.55 \pm 3.56 & 45.46 \pm 0.42 & 38.51 \pm 0.81 & {36.6} & {\textbf{64.6}} \\
# hopper-medium-replay-v2 & \textbf{100.78} \textbf{$\pm$} \textbf{2.08} & \textbf{99.90} \textbf{$\pm$} \textbf{0.15} & \textbf{99.12} \textbf{$\pm$} \textbf{1.00} & 78.88 \pm 6.56 & {82.7} & {98.5} \\
# walker2d-medium-replay-v2 & \textbf{90.64} \textbf{$\pm$} \textbf{1.05} & 76.26 \pm 3.89 & 87.60 \pm 0.50 & 54.77 \pm 3.14 & {66.6} & {82.9} \\
# \hline
# Avg All & {\textbf{74.63}} & {25.81} & {\textbf{76.80}} & {64.12} & {-} & {-} \\
# Avg Reported & {74.63} & {25.81} & {\textbf{76.80}} & {64.12} & {74.73} & {72.66} \\
# \hline
# \end{array}

# %%
# %matplotlib inline
# %run plot_ablation_offline.py
